# %%
import pandas as pd
import matplotlib as plt

popularities = pd.read_csv("newConversion.csv")

popularities.head()
# Out:
#    round    Jeremiah      Sharon       David        Adam      Samuel  \
# 0      0  100.000000  100.000000  100.000000  100.000000  100.000000
# 1      1   99.500000  102.750000   89.362500  132.300000  110.487500
# 2      2   92.108234  121.425875   91.979094  107.290518  118.856269
# 3      3   76.654008  138.613844  107.098002  104.421940  133.171924
# 4      4   86.059214  144.852429  127.638549  106.358283  152.904332
#
#         Aaron      Joseph  Melchizedek
# 0  100.000000  100.000000   100.000000
# 1   93.000000  109.250000   104.375000
# 2  106.789297  132.293875   122.476234
# 3  109.417456  148.116765   134.445302
# 4  123.933690  138.128937   128.382038

# %%
popularities.plot(x='round', figsize=(14,6))
# Out:
# <Axes: xlabel='round'>
